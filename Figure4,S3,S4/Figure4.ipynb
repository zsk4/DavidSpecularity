# %%
# 16 April 2025
# Zachary Katz
# zachary_katz@mines.edu

"""
Plot Figure 4, S2, S3 using output from Figure4.py saved as csv files in the output directory

"""

# Imports and options
import os

import shapefile
import numpy as np
import xarray as xr
import scipy
import skimage

import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from mpl_toolkits.axes_grid1.anchored_artists import AnchoredSizeBar
import cartopy.crs as ccrs
import matplotlib.patheffects as pe
from scipy.spatial import cKDTree
from scipy.optimize import curve_fit
import geopandas as gpd
import matplotlib.colors as colors
from matplotlib.lines import Line2D
import matplotlib.cm as cm
from concurrent.futures import ProcessPoolExecutor
import pandas as pd
from pyproj import CRS, Transformer

# %matplotlib inline

# %%
# Set paths and make output directory
offset_video_path_1819 = '../_Data/UTG_1819_OffsetVideo'
offset_video_path_1617 = '../_Data/UTG_1617_OffsetVideo'
lake_path = '../_Data/Ju_SLD2'
outdir = './_OutputFigures'
csv_dir = './output750m_win_250m_ovlp'
evolving_path = '../_Data/Sauthoff_EvolvingOutlines'
DDInSAR_path = '../_Data/Kim_DDInSAR'
os.makedirs(outdir, exist_ok=True)

# Load KRT2 offset video netcdf files

file_paths_1819 = [os.path.join(offset_video_path_1819, f) for f in os.listdir(offset_video_path_1819) if f.endswith('.nc')]
file_paths_1617 = [os.path.join(offset_video_path_1617, f) for f in os.listdir(offset_video_path_1617) if f.endswith('.nc')]

offset_video_radargrams_1819 = []
for f in file_paths_1819:
    offset_video_radargram = xr.open_dataset(f, decode_timedelta=True)
    offset_video_radargrams_1819.append(offset_video_radargram)

offset_video_radargrams_1819.sort(key=lambda x: x.transect_id)
offset_video_radargrams_1819[0]

offset_video_radargrams_1617 = []
for f in file_paths_1617:
    offset_video_radargram = xr.open_dataset(f, decode_timedelta=True)
    offset_video_radargrams_1617.append(offset_video_radargram)

offset_video_radargrams_1617.sort(key=lambda x: x.transect_id)
offset_video_radargrams_1617[0]


# Remove radargram.transect_id for x in ['X21b', 'X27b'] from offsert_video_radargrams_1819
offset_video_radargrams_1819 = [rg for rg in offset_video_radargrams_1819 if not any(x in rg.transect_id for x in ['X21a', 'X27a'])]

len(offset_video_radargrams_1819), len(offset_video_radargrams_1617)
# Out:
# (40, 11)

# %%
# Helper functions
def ll2xy(lon: list[float], lat: list[float]) -> tuple[list[float], list[float]]:
    """
    Transform coordinates from input geodetic coordinates (lon, lat)
    to output Antarctic Polar Stereographic coordinates (x, y).
    Can also take single floats.

    Parameters
    ----------
    lon: list[float]
         Geodetic longitude in EPSG:4326
    lat: list[float]
         Geodetic latitude in EPSG:4326

    Returns
    -------
    x: list[float]
       Antarctic Polar Stereographic (EPSG:3031) x
    y: list[float]
       Antarctic Polar Stereographic (EPSG:3031) y
    """

    crs_ll = CRS("EPSG:4326")
    crs_xy = CRS("EPSG:3031")
    ll_to_xy = Transformer.from_crs(crs_ll, crs_xy, always_xy=True)
    x, y = ll_to_xy.transform(lon, lat)
    return x, y

# %%
# Load Subglacial Lake Cheongsuk shapefile
pathA = lake_path + '/SLD2-A.shp'
pathB = lake_path + '/SLD2-B.shp'
pathC = lake_path + '/SLD2-C.shp'

xs_lake = []
ys_lake = []
for path in [pathA, pathB, pathC]:
    sf = shapefile.Reader(path)
    shapes = sf.shapes()
    for shp in shapes:
        points = shp.points
        x = [p[0] for p in points]
        y = [p[1] for p in points]
    xs_lake.append(x)
    ys_lake.append(y)

# %%
# Convert from spatial freq width to doppler width
MS_TO_KMHR = 3.6
for radargram in offset_video_radargrams_1819[:]:
    avg_distance = np.mean(np.diff(radargram['distance'].values))

    time = (radargram['time'][-1] - radargram['time'][0])
    time = time / np.timedelta64(1, 's')
    
    velocity = (radargram['distance'][-1] - radargram['distance'][0]).values / time #m/s
    radargram['avg_velocity']  = velocity

    dt = np.gradient(radargram.time.values.astype('datetime64[ns]').astype('int64')) / 1e9 # seconds
    dd = np.gradient(radargram.distance.values) # meters
    radargram['velocity'] = (('distance',), dd/ dt)

for radargram in offset_video_radargrams_1617[:]:
    avg_distance = np.mean(np.diff(radargram['distance'].values))

    time = (radargram['time'][-1] - radargram['time'][0])
    time = time / np.timedelta64(1, 's')
    
    velocity = (radargram['distance'][-1] - radargram['distance'][0]).values / time #m/s
    radargram['avg_velocity']  = velocity

    dt = np.gradient(radargram.time.values.astype('datetime64[ns]').astype('int64')) / 1e9 # seconds
    dd = np.gradient(radargram.distance.values) # meters
    radargram['velocity'] = (('distance',), dd/ dt)

# %%
# Load csv files
plotting_dict_1819_csv = pd.read_csv(os.path.join(csv_dir, 'plotting_dict_1819.csv'))
plotting_dict_1819 = {'x_centers':[plotting_dict_1819_csv['x_centers']], 'y_centers':[plotting_dict_1819_csv['y_centers'].to_list()],'ridge_params_list':[plotting_dict_1819_csv['ridge_params_list'].to_list()], 'velocities':[plotting_dict_1819_csv['velocities'].to_list()]}
plotting_dict_1617_csv = pd.read_csv(os.path.join(csv_dir, 'plotting_dict_1617.csv'))
plotting_dict = {'x_centers':[plotting_dict_1617_csv['x_centers'].to_list()], 'y_centers':[plotting_dict_1617_csv['y_centers'].to_list()],'ridge_params_list':[plotting_dict_1617_csv['ridge_params_list'].to_list()], 'velocities':[plotting_dict_1617_csv['velocities'].to_list()]}

# %%
plotting_dict_1819_csv['x_centers'][0]
# Out:
# '[np.float64(677871.4080036522), np.float64(677382.1547221834), np.float64(676889.0671791878), np.float64(676393.8252905526), np.float64(675901.8837007753), np.float64(675413.0522487446), np.float64(674921.0592872199), np.float64(674428.117047601), np.float64(673936.1403042721), np.float64(673442.5965448386), np.float64(672951.8287302229), np.float64(672461.4781830893), np.float64(671968.8188486121), np.float64(671474.6064532975), np.float64(670981.5388581807), np.float64(670490.6237988453), np.float64(669997.8390852993), np.float64(669506.2921383176), np.float64(669015.1127552404), np.float64(668522.7911470273), np.float64(668030.931364839), np.float64(667537.890310633), np.float64(667044.355617484), np.float64(666551.4998299639), np.float64(666059.3408449967), np.float64(665568.0823783468), np.float64(665076.9398080619), np.float64(664584.4212706402), np.float64(664091.5431583908), np.float64(663597.4342525868), np.float64(663101.4944678491), np.float64(662609.5578527325), np.float64(662121.1229844968), np.float64(661630.1077695838), np.float64(661137.4953263894), np.float64(660647.0281214907), np.float64(660156.5823758331), np.float64(659663.6272401586), np.float64(659170.1760231891), np.float64(658678.0762758004), np.float64(658186.1375679382), np.float64(657693.9774902791), np.float64(657200.5797848927), np.float64(656706.7534099633), np.float64(656213.1438375973), np.float64(655720.3014645855)]'

# %%
velocities_1819 = []
for radargram, center_list in zip(offset_video_radargrams_1819[:], plotting_dict_1819['x_centers'][:]):
    velocities = []
    
    print(center_list[0])
    for center in center_list[0][:]:
        print(center)
        print(radargram['x'].compute().values)
        idx = np.argmin(np.abs(radargram['x'].compute().values - center))
        velocities.append(radargram['velocity'][idx].values)
    
    velocities_1819.append(velocities)
  
velocities_1617 = []
for radargram, center_list in zip(offset_video_radargrams_1617[:], plotting_dict['x_centers'][:]):
    velocities = []
    
    for center in center_list[:]:
        idx = np.argmin(np.abs(radargram['x'].compute().values - center))
        velocities.append(radargram['velocity'][idx].values)
    
    velocities_1617.append(velocities)  

plotting_dict_1819['velocities'] = velocities_1819
plotting_dict['velocities'] = velocities_1617
# Out:
# [np.float64(677871.4080036522), np.float64(677382.1547221834), np.float64(676889.0671791878), np.float64(676393.8252905526), np.float64(675901.8837007753), np.float64(675413.0522487446), np.float64(674921.0592872199), np.float64(674428.117047601), np.float64(673936.1403042721), np.float64(673442.5965448386), np.float64(672951.8287302229), np.float64(672461.4781830893), np.float64(671968.8188486121), np.float64(671474.6064532975), np.float64(670981.5388581807), np.float64(670490.6237988453), np.float64(669997.8390852993), np.float64(669506.2921383176), np.float64(669015.1127552404), np.float64(668522.7911470273), np.float64(668030.931364839), np.float64(667537.890310633), np.float64(667044.355617484), np.float64(666551.4998299639), np.float64(666059.3408449967), np.float64(665568.0823783468), np.float64(665076.9398080619), np.float64(664584.4212706402), np.float64(664091.5431583908), np.float64(663597.4342525868), np.float64(663101.4944678491), np.float64(662609.5578527325), np.float64(662121.1229844968), np.float64(661630.1077695838), np.float64(661137.4953263894), np.float64(660647.0281214907), np.float64(660156.5823758331), np.float64(659663.6272401586), np.float64(659170.1760231891), np.float64(658678.0762758004), np.float64(658186.1375679382), np.float64(657693.9774902791), np.float64(657200.5797848927), np.float64(656706.7534099633), np.float64(656213.1438375973), np.float64(655720.3014645855)]
# [
# [678241.1782     678240.18498209 678239.19184185 ... 655220.58600921
#  655219.58618726 655218.58634862]
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[52], line 9
#       7     print(center)
#       8     print(radargram['x'].compute().values)
# ----> 9     idx = np.argmin(np.abs(radargram['x'].compute().values - center))
#      10     velocities.append(radargram['velocity'][idx].values)
#      12 velocities_1819.append(velocities)
#
# UFuncTypeError: ufunc 'subtract' did not contain a loop with signature matching types (dtype('float64'), dtype('<U1')) -> None

# %%
# Plot plan view comparison, scaled by velocity
def plot_radargram_planview_width_velocity(ax, xs_lake, ys_lake, plot_dict, rad_vel):
    """
    Plot doppler width and lake outline map view
    """

    bbox = [650000,-1475000,680000,-1430000] #David_SGL2_full extent

    # Remove borders
    ax.patch.set_facecolor("none")
    for spine in ax.spines.values():
        spine.set_visible(False)
    ax.set_xticks([])
    ax.set_yticks([])

    velocities = [rad['avg_velocity'] for rad in rad_vel[:]]
    for x_center_list, y_center_list, plotting,velocity in zip(plot_dict['x_centers'], plot_dict['y_centers'], plot_dict['ridge_params_list'], velocities):
        width = [rp['right'] - rp['left'] for rp in plotting]
        scaled_width = [w * velocity for w in width]  # Scale by velocity to get doppler width
        
        y_maxes = np.array([rp['y_at_max'] for rp in plotting])
        mask = y_maxes < 1250
        scaled_width = np.array([sw.item() for sw in scaled_width])
        scaled_width[mask] = np.nan


        #print(min(scaled_width), max(scaled_width))
        cb = ax.scatter(x_center_list, y_center_list, c=scaled_width, cmap='viridis', s=30, zorder=4,vmin=0,vmax=900)

    for x, y in zip(xs_lake, ys_lake):
        ax.plot(x, y, color='white', linewidth=2.5, zorder=5)

    # Add colorbar
    k_cbar_anchor = (0,0)
    cbbox = inset_axes(ax, width=3,height=1,
                    bbox_to_anchor=k_cbar_anchor,
                    bbox_transform=ax.transAxes, loc="center left")
    [cbbox.spines[k].set_visible(False) for k in cbbox.spines]
    cbbox.tick_params(
        axis = 'both',
        left = False,
        top = False,
        right = False,
        bottom = False,
        labelleft = False,
        labeltop = False,
        labelright = False,
        labelbottom = False
    )
    cbbox.set_facecolor([0,0,0,0.9])

    cbaxes = inset_axes(cbbox, '92%', '20%', loc = 'center')
    cbar=fig.colorbar(cb,cax=cbaxes, orientation='horizontal',extend='max') #make colorbar
    cbar.outline.set_edgecolor('white')
    cbar.outline.set_linewidth(1)
    cbar.ax.tick_params(labelsize=14, color='white', labelcolor='white')
    cbar.set_label(r"Doppler Width [Hz]", fontsize=15, color='white')
    cbar.ax.xaxis.set_label_position('top')

    cbar.ax.minorticks_on()

    ax.set_xlim(bbox[0],bbox[2])
    ax.set_ylim(bbox[1],bbox[3])
    #ax.set_title(f"Window = {win_m} m, Overlap = {ovlp_m} m", fontsize=16)

    return fig


ps71_projection = ccrs.Stereographic(central_latitude=-90, central_longitude=0, true_scale_latitude=-71)
fig, ax = plt.subplots(figsize=(8,8), subplot_kw={'projection': ps71_projection})

plot_radargram_planview_width_velocity(ax, xs_lake, ys_lake, plotting_dict_1819, offset_video_radargrams_1819)
scalebar = AnchoredSizeBar(ax.transData, 5000, '5 km', 'upper left', pad=1.5, color='black', frameon=False, size_vertical=300, fontproperties={'size': 14})
ax.add_artist(scalebar)

#bbox = [650000,-1475000,680000,-1430000] #David_SGL2_full extent
# Glacial Flow Direction Arrow
ax.annotate(
    '',
    xy=(659000, -1436000),      # arrow tip (downstream)
    xytext=(664000, -1431000),  # arrow tail
    arrowprops=dict(
        arrowstyle='-|>',       # filled arrow head
        color='black',
        lw=2,
        mutation_scale=20 ,      # controls head size
    ),
    transform=ps71_projection,
    zorder=10
)

ax.text(664000, -1432000, ' Ice Flow\nDirection',
        fontsize=14, color='black', ha='left', va='center',zorder=10)

# Lakeb lakes A, B, C
ax.annotate('A', xy=(657000, -1446000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection,zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])
ax.annotate('B', xy=(664200, -1454000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection, zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])
ax.annotate('C', xy=(668500, -1458000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection,zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])

# Set background gainsboro
fig.patch.set_facecolor('gainsboro')

fig.savefig(os.path.join(outdir, 'Doppler_width_map.png'), dpi=300, bbox_inches='tight')
# Out:
# [165.18275424 502.29041595 214.06336518 357.33412141 399.47257912
#  470.26518808 512.4036458  697.81285974 616.90702093 650.6177871
#  608.47932938 357.33412141 252.83074628 546.11441197 478.69287963
#  350.59196818 451.72426669 365.76181295          nan 148.32737115
#  232.60428658          nan          nan 193.83690548          nan
#  510.71810749 603.42271446 444.98211345          nan 321.93781693
#  284.85597414 274.74274429 165.18275424 170.23936916 294.96920399
#  273.05720598 385.98827266 465.20857316 529.25902888 529.25902888
#  574.76856321 593.30948461 458.46641992 316.88120201 264.62951444
#   35.39630448]
# [343.22911208 430.65539535 458.17848452 458.17848452 302.75398094
#  280.0879075  247.70780259 250.94581308 147.32947736          nan
#  273.61188652 208.85167669 179.70958227 233.13675538 281.70691275
#  226.66073439 231.51775013 192.66162423 145.71047211 111.71136195
#   25.90408393          nan          nan 118.18738293          nan
#  305.99199143 288.18293373 294.65895471 349.70513306 349.70513306
#  317.32502815 254.18382357 208.85167669  22.66607344 155.42450358
#  144.09146686          nan 270.37387603 132.75843014  33.99911016
#           nan          nan 132.75843014          nan          nan]

# %%
# 1617 Scaled by velocity
ps71_projection = ccrs.Stereographic(central_latitude=-90, central_longitude=0, true_scale_latitude=-71)
fig, ax = plt.subplots(figsize=(8,8), subplot_kw={'projection': ps71_projection})

plot_radargram_planview_width_velocity(ax, xs_lake, ys_lake, plotting_dict, offset_video_radargrams_1617)
scalebar = AnchoredSizeBar(ax.transData, 5000, '5 km', 'upper left', pad=1.5, color='black', frameon=False, size_vertical=300, fontproperties={'size': 14})
ax.add_artist(scalebar)

#bbox = [650000,-1475000,680000,-1430000] #David_SGL2_full extent
# Glacial Flow Direction Arrow
ax.annotate(
    '',
    xy=(659000, -1436000),      # arrow tip (downstream)
    xytext=(664000, -1431000),  # arrow tail
    arrowprops=dict(
        arrowstyle='-|>',       # filled arrow head
        color='black',
        lw=2,
        mutation_scale=20 ,      # controls head size
    ),
    transform=ps71_projection,
    zorder=10
)

ax.text(664000, -1432000, ' Ice Flow\nDirection',
        fontsize=14, color='black', ha='left', va='center',zorder=10)

# Lakeb lakes A, B, C
ax.annotate('A', xy=(657000, -1446000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection,zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])
ax.annotate('B', xy=(664200, -1454000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection, zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])
ax.annotate('C', xy=(668500, -1458000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection,zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])

# Set background gainsboro
fig.patch.set_facecolor('gainsboro')

fig.savefig(os.path.join(outdir, 'Doppler_width_map.png'), dpi=300, bbox_inches='tight')

# %%
# Plot difference

# Find points within 100 km of each other in the two datasets
coords_1819 = np.column_stack((
    np.concatenate(plotting_dict_1819['x_centers']),
    np.concatenate(plotting_dict_1819['y_centers'])
))

coords_1617 = np.column_stack((
    np.concatenate(plotting_dict['x_centers']),
    np.concatenate(plotting_dict['y_centers'])
))

ridge_params_1819 = [r for sublist in plotting_dict_1819['ridge_params_list'] for r in sublist]
ridge_params_1617 = [r for sublist in plotting_dict['ridge_params_list'] for r in sublist]

# Compute width (abs(left-right)) for each sub-point
width_1819 = np.array([abs(r['left'] - r['right']) for r in ridge_params_1819])
width_1617 = np.array([abs(r['left'] - r['right']) for r in ridge_params_1617])

# Compute scaled_width by multiplying by velocity
width_velocity_scaled_1819 = np.concatenate(velocities_1819) * width_1819
width_velocity_scaled_1617 = np.concatenate(velocities_1617) * width_1617

print(len(plotting_dict_1819['x_centers']))
print(len(plotting_dict_1819['y_centers']))
print(len(plotting_dict['x_centers']))
print(len(plotting_dict['y_centers']))
print(len(width_1819))
print(len(width_1617))
print(len(width_velocity_scaled_1819))
print(len(width_velocity_scaled_1617))

tree_1617 = cKDTree(coords_1617)

dist, idx = tree_1617.query(coords_1819)

mask = dist <= 500

matched_coords = coords_1819[mask]
ridge_diff = width_1819[mask] - width_1617[idx[mask]]
ridge_diff_velocity_scaled = width_velocity_scaled_1819[mask] - width_velocity_scaled_1617[idx[mask]]
# Out:
# 40
# 40
# 11
# 11
# 2024
# 2675
# 2024
# 2675

# %%
ps71_projection = ccrs.Stereographic(central_latitude=-90, central_longitude=0, true_scale_latitude=-71)
fig, ax = plt.subplots(figsize=(8,8), subplot_kw={'projection': ps71_projection})

scalebar = AnchoredSizeBar(ax.transData, 5000, '5 km', 'upper left', pad=1.5, color='black', frameon=False, size_vertical=300, fontproperties={'size': 14})
ax.add_artist(scalebar)

#bbox = [650000,-1475000,680000,-1430000] #David_SGL2_full extent
# Glacial Flow Direction Arrow
ax.annotate(
    '',
    xy=(659000, -1436000),      # arrow tip (downstream)
    xytext=(664000, -1431000),  # arrow tail
    arrowprops=dict(
        arrowstyle='-|>',       # filled arrow head
        color='black',
        lw=2,
        mutation_scale=20 ,      # controls head size
    ),
    transform=ps71_projection,
    zorder=10
)

ax.text(664000, -1432000, ' Ice Flow\nDirection',
        fontsize=14, color='black', ha='left', va='center',zorder=10)

bbox = [650000,-1475000,680000,-1430000] #David_SGL2_full extent

# Remove borders
ax.patch.set_facecolor("none")
for spine in ax.spines.values():
    spine.set_visible(False)
ax.set_xticks([])
ax.set_yticks([])

for x, y in zip(xs_lake, ys_lake):
    ax.plot(x, y, color='white', linewidth=2.5, zorder=5)

# Add colorbar
k_cbar_anchor = (0,0)
cbbox = inset_axes(ax, width=3.5,height=1,
                bbox_to_anchor=k_cbar_anchor,
                bbox_transform=ax.transAxes, loc="center left")
[cbbox.spines[k].set_visible(False) for k in cbbox.spines]
cbbox.tick_params(
    axis = 'both',
    left = False,
    top = False,
    right = False,
    bottom = False,
    labelleft = False,
    labeltop = False,
    labelright = False,
    labelbottom = False
)
cbbox.set_facecolor([0,0,0,0.9])

cb = ax.scatter(matched_coords[:,0], matched_coords[:,1], c=ridge_diff_velocity_scaled, cmap='seismic', s=30, zorder=4,vmin=-600,vmax=600) # Dummy scatter for colorbar
cbaxes = inset_axes(cbbox, '92%', '20%', loc = 'center')
cbar=fig.colorbar(cb,cax=cbaxes, orientation='horizontal') #make colorbar
cbar.outline.set_edgecolor('white')
cbar.outline.set_linewidth(1)
cbar.ax.tick_params(labelsize=14, color='white', labelcolor='white')
cbar.set_label(r"2018-2019 $-$ 2016-2017", fontsize=15, color='white')
cbar.ax.xaxis.set_label_position('top')

cbar.ax.minorticks_on()

ax.set_xlim(bbox[0],bbox[2])
ax.set_ylim(bbox[1],bbox[3])
#ax.set_title(f"Window = {win_m} m, Overlap = {ovlp_m} m", fontsize=16)


# Lakeb lakes A, B, C
ax.annotate('A', xy=(657000, -1446000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection,zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])
ax.annotate('B', xy=(664200, -1454000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection, zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])
ax.annotate('C', xy=(668500, -1458000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection,zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])

# Set background gainsboro
fig.patch.set_facecolor('gainsboro')

# %%
# Crossover error with self
coords = []
width = []
width_velocity_corrected = []
line_id = []

all_velocities_1819 = np.concatenate(plotting_dict_1819['velocities'])
avg_velocity_1819 = np.mean(all_velocities_1819)

all_velocities_1617 = np.concatenate(plotting_dict['velocities'])
avg_velocity_1617 = np.mean(all_velocities_1617)

# %%
for i, (xs, ys, ridge_list, velocity) in enumerate(zip(
        plotting_dict_1819['x_centers'],
        plotting_dict_1819['y_centers'],
        plotting_dict_1819['ridge_params_list'],
        plotting_dict_1819['velocities'])):

    n = len(xs)

    coords.append(np.column_stack((xs, ys)))
    # Extend by the width of each ridge, scaled by velocity
    width_velocity_corrected.extend([abs(r['left'] - r['right']) * velocity[j] for j, r in enumerate(ridge_list)])
    #avg_velocity = np.mean(velocity)
    width.extend([abs(r['left'] - r['right'])*avg_velocity_1819 for r in ridge_list])
    line_id.extend([i]*n)

coords = np.vstack(coords)
width = np.array(width)
width_velocity_corrected = np.array(width_velocity_corrected)
line_id = np.array(line_id)

tree = cKDTree(coords)

pairs = np.array(list(tree.query_pairs(r=500)))

i, j = pairs[:,0], pairs[:,1]

mask = line_id[i] != line_id[j]

i = i[mask]
j = j[mask]

ridge_diff_1819 = np.abs(width[i] - width[j])
ridge_diff_velocity_corrected_1819 = np.abs(width_velocity_corrected[i] - width_velocity_corrected[j])

coords_i = coords[i]
coords_j = coords[j]

x_cross_1819 = (coords[i,0] + coords[j,0]) / 2
y_cross_1819 = (coords[i,1] + coords[j,1]) / 2

# %%
ps71_projection = ccrs.Stereographic(central_latitude=-90, central_longitude=0, true_scale_latitude=-71)
fig, ax = plt.subplots(figsize=(8,8), subplot_kw={'projection': ps71_projection})

scalebar = AnchoredSizeBar(ax.transData, 5000, '5 km', 'upper left', pad=1.5, color='black', frameon=False, size_vertical=300, fontproperties={'size': 14})
ax.add_artist(scalebar)

#bbox = [650000,-1475000,680000,-1430000] #David_SGL2_full extent
# Glacial Flow Direction Arrow
ax.annotate(
    '',
    xy=(659000, -1436000),      # arrow tip (downstream)
    xytext=(664000, -1431000),  # arrow tail
    arrowprops=dict(
        arrowstyle='-|>',       # filled arrow head
        color='black',
        lw=2,
        mutation_scale=20 ,      # controls head size
    ),
    transform=ps71_projection,
    zorder=10
)

ax.text(664000, -1432000, ' Ice Flow\nDirection',
        fontsize=14, color='black', ha='left', va='center',zorder=10)

bbox = [650000,-1475000,680000,-1430000] #David_SGL2_full extent

# Remove borders
ax.patch.set_facecolor("none")
for spine in ax.spines.values():
    spine.set_visible(False)
ax.set_xticks([])
ax.set_yticks([])

for x, y in zip(xs_lake, ys_lake):
    ax.plot(x, y, color='white', linewidth=2.5, zorder=5)

# Add colorbar
k_cbar_anchor = (0,0)
cbbox = inset_axes(ax, width=3.5,height=1,
                bbox_to_anchor=k_cbar_anchor,
                bbox_transform=ax.transAxes, loc="center left")
[cbbox.spines[k].set_visible(False) for k in cbbox.spines]
cbbox.tick_params(
    axis = 'both',
    left = False,
    top = False,
    right = False,
    bottom = False,
    labelleft = False,
    labeltop = False,
    labelright = False,
    labelbottom = False
)
cbbox.set_facecolor([0,0,0,0.9])

cb = ax.scatter(x_cross_1819, y_cross_1819, c=ridge_diff_velocity_corrected_1819, cmap='viridis', s=30, zorder=4,vmin=0,vmax=600) # Dummy scatter for colorbar
cbaxes = inset_axes(cbbox, '92%', '20%', loc = 'center')
cbar=fig.colorbar(cb,cax=cbaxes, orientation='horizontal') #make colorbar
cbar.outline.set_edgecolor('white')
cbar.outline.set_linewidth(1)
cbar.ax.tick_params(labelsize=14, color='white', labelcolor='white')
cbar.set_label(r"Crossover Difference [Hz]", fontsize=15, color='white')
cbar.ax.xaxis.set_label_position('top')

cbar.ax.minorticks_on()

ax.set_xlim(bbox[0],bbox[2])
ax.set_ylim(bbox[1],bbox[3])
#ax.set_title(f"Window = {win_m} m, Overlap = {ovlp_m} m", fontsize=16)


# Lakeb lakes A, B, C
ax.annotate('A', xy=(657000, -1446000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection,zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])
ax.annotate('B', xy=(664200, -1454000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection, zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])
ax.annotate('C', xy=(668500, -1458000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection,zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])

# Set background gainsboro
fig.patch.set_facecolor('gainsboro')

# %%
# Hist of absolute ridge difference
fig, ax = plt.subplots(figsize=(8,6))

# Combine data to get common bins
all_data = np.concatenate([ridge_diff_velocity_corrected_1819, ridge_diff_1819])
bins = np.linspace(all_data.min(), all_data.max(), 26) 

ax.hist(ridge_diff_velocity_corrected_1819, bins=bins, color='purple',alpha=0.7, edgecolor='black')
ax.hist(ridge_diff_1819, bins=bins, color='orange',alpha=0.7, edgecolor='black')
# Boxplot
#ax.boxplot(abs_ridge_diff, vert=False, patch_artist=True, boxprops=dict(facecolor='purple', color='black'), medianprops=dict(color='yellow'))
ax.set_xlabel('Abs Crossover Difference [Hz]', fontsize=16)
ax.set_ylabel('Count', fontsize=16)
ax.tick_params(labelsize=14)
ax.text(0.95, 0.6, f'2018-2019', transform=ax.transAxes, fontsize=14, verticalalignment='top', horizontalalignment='right')

ax.legend(['Point-Velocity', 'Average Velocity'], fontsize=14, loc='upper right', frameon=False)

# %%
# Crossover error with self
coords = []
width = []
width_velocity_corrected = []
line_id = []

for i, (xs, ys, ridge_list, velocity) in enumerate(zip(
        plotting_dict['x_centers'],
        plotting_dict['y_centers'],
        plotting_dict['ridge_params_list'],
        plotting_dict['velocities'])):

    n = len(xs)

    coords.append(np.column_stack((xs, ys)))
    # Extend by the width of each ridge, scaled by velocity
    width_velocity_corrected.extend([abs(r['left'] - r['right']) * velocity[j] for j, r in enumerate(ridge_list)])
    avg_velocity = np.mean(velocity)
    width.extend([abs(r['left'] - r['right'])*avg_velocity_1617 for r in ridge_list])
    line_id.extend([i]*n)

coords = np.vstack(coords)
width = np.array(width)
width_velocity_corrected = np.array(width_velocity_corrected)
line_id = np.array(line_id)

tree = cKDTree(coords)

pairs = np.array(list(tree.query_pairs(r=500)))

i, j = pairs[:,0], pairs[:,1]

mask = line_id[i] != line_id[j]

i = i[mask]
j = j[mask]

ridge_diff_1617 = np.abs(width[i] - width[j])
ridge_diff_velocity_corrected_1617 = np.abs(width_velocity_corrected[i] - width_velocity_corrected[j])

coords_i = coords[i]
coords_j = coords[j]

x_cross = (coords[i,0] + coords[j,0]) / 2
y_cross = (coords[i,1] + coords[j,1]) / 2

# %%
ps71_projection = ccrs.Stereographic(central_latitude=-90, central_longitude=0, true_scale_latitude=-71)
fig, ax = plt.subplots(figsize=(8,8), subplot_kw={'projection': ps71_projection})

scalebar = AnchoredSizeBar(ax.transData, 5000, '5 km', 'upper left', pad=1.5, color='black', frameon=False, size_vertical=300, fontproperties={'size': 14})
ax.add_artist(scalebar)

#bbox = [650000,-1475000,680000,-1430000] #David_SGL2_full extent
# Glacial Flow Direction Arrow
ax.annotate(
    '',
    xy=(659000, -1436000),      # arrow tip (downstream)
    xytext=(664000, -1431000),  # arrow tail
    arrowprops=dict(
        arrowstyle='-|>',       # filled arrow head
        color='black',
        lw=2,
        mutation_scale=20 ,      # controls head size
    ),
    transform=ps71_projection,
    zorder=10
)

ax.text(664000, -1432000, ' Ice Flow\nDirection',
        fontsize=14, color='black', ha='left', va='center',zorder=10)

bbox = [650000,-1475000,680000,-1430000] #David_SGL2_full extent

# Remove borders
ax.patch.set_facecolor("none")
for spine in ax.spines.values():
    spine.set_visible(False)
ax.set_xticks([])
ax.set_yticks([])

for x, y in zip(xs_lake, ys_lake):
    ax.plot(x, y, color='white', linewidth=2.5, zorder=5)

# Add colorbar
k_cbar_anchor = (0,0)
cbbox = inset_axes(ax, width=3.5,height=1,
                bbox_to_anchor=k_cbar_anchor,
                bbox_transform=ax.transAxes, loc="center left")
[cbbox.spines[k].set_visible(False) for k in cbbox.spines]
cbbox.tick_params(
    axis = 'both',
    left = False,
    top = False,
    right = False,
    bottom = False,
    labelleft = False,
    labeltop = False,
    labelright = False,
    labelbottom = False
)
cbbox.set_facecolor([0,0,0,0.9])

cb = ax.scatter(x_cross, y_cross, c=ridge_diff_velocity_corrected_1617, cmap='viridis', s=30, zorder=4,vmin=0,vmax=600) # Dummy scatter for colorbar
cbaxes = inset_axes(cbbox, '92%', '20%', loc = 'center')
cbar=fig.colorbar(cb,cax=cbaxes, orientation='horizontal') #make colorbar
cbar.outline.set_edgecolor('white')
cbar.outline.set_linewidth(1)
cbar.ax.tick_params(labelsize=14, color='white', labelcolor='white')
cbar.set_label(r"Crossover Difference [Hz]", fontsize=15, color='white')
cbar.ax.xaxis.set_label_position('top')

cbar.ax.minorticks_on()

ax.set_xlim(bbox[0],bbox[2])
ax.set_ylim(bbox[1],bbox[3])
#ax.set_title(f"Window = {win_m} m, Overlap = {ovlp_m} m", fontsize=16)


# Lakeb lakes A, B, C
ax.annotate('A', xy=(657000, -1446000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection,zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])
ax.annotate('B', xy=(664200, -1454000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection, zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])
ax.annotate('C', xy=(668500, -1458000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection,zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])

# Set background gainsboro
fig.patch.set_facecolor('gainsboro')

# %%
# Hist of absolute ridge difference
fig, ax = plt.subplots(figsize=(8,6))

# Combine data to get common bins
all_data = np.concatenate([ridge_diff_velocity_corrected_1617, ridge_diff_1617])
bins = np.linspace(all_data.min(), all_data.max(), 20) 

ax.hist(ridge_diff_velocity_corrected_1617, bins=bins, color='purple',alpha=0.7, edgecolor='black')
ax.hist(ridge_diff_1617, bins=bins, color='orange',alpha=0.7, edgecolor='black')
# Boxplot
#ax.boxplot(abs_ridge_diff, vert=False, patch_artist=True, boxprops=dict(facecolor='purple', color='black'), medianprops=dict(color='yellow'))
ax.set_xlabel('Abs Crossover Difference [Hz]', fontsize=16)
ax.set_ylabel('Count', fontsize=16)
ax.tick_params(labelsize=14)
ax.text(0.95, 0.6, f'2016-2017', transform=ax.transAxes, fontsize=14, verticalalignment='top', horizontalalignment='right')

ax.legend(['Point-Velocity', 'Average Velocity'], fontsize=14, loc='upper right', frameon=False)

# %%
offset_video_radargrams_1819
# Out:
# [<xarray.Dataset> Size: 899MB
#  Dimensions:       (distance: 23382, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 187kB 0.0 1.0 2.0 ... 2.338e+04 2.338e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 187kB ...
#      y             (distance) float64 187kB ...
#      h             (distance) float64 187kB ...
#      time          (distance) datetime64[ns] 187kB 2018-11-17T00:36:44.464500 ...
#      bxds7         (distance, fast_time) int16 150MB ...
#      bxds6         (distance, fast_time) int16 150MB ...
#      bxds5         (distance, fast_time) int16 150MB ...
#      bxds1         (distance, fast_time) int16 150MB ...
#      bxds8         (distance, fast_time) int16 150MB ...
#      bxds2         (distance, fast_time) int16 150MB ...
#      avg_velocity  float64 8B 34.38
#      velocity      (distance) float64 187kB 26.74 26.74 26.74 ... 35.78 35.84
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X10a
#      history:         Created on Sun Jan  4 16:46:26 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 880MB
#  Dimensions:       (distance: 22889, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 183kB 0.0 1.0 2.0 ... 2.289e+04 2.289e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 183kB ...
#      y             (distance) float64 183kB ...
#      h             (distance) float64 183kB ...
#      time          (distance) datetime64[ns] 183kB 2018-11-18T02:23:03.100600 ...
#      bxds5         (distance, fast_time) int16 146MB ...
#      bxds6         (distance, fast_time) int16 146MB ...
#      bxds7         (distance, fast_time) int16 146MB ...
#      bxds8         (distance, fast_time) int16 146MB ...
#      bxds2         (distance, fast_time) int16 146MB ...
#      bxds1         (distance, fast_time) int16 146MB ...
#      avg_velocity  float64 8B 35.21
#      velocity      (distance) float64 183kB 39.37 39.37 39.37 ... 34.96 34.96
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X11a
#      history:         Created on Sun Jan  4 16:46:58 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 931MB
#  Dimensions:       (distance: 24206, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 194kB 0.0 1.0 2.0 ... 2.42e+04 2.42e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 194kB ...
#      y             (distance) float64 194kB ...
#      h             (distance) float64 194kB ...
#      time          (distance) datetime64[ns] 194kB 2018-11-17T02:40:24.390500 ...
#      bxds6         (distance, fast_time) int16 155MB ...
#      bxds7         (distance, fast_time) int16 155MB ...
#      bxds5         (distance, fast_time) int16 155MB ...
#      bxds1         (distance, fast_time) int16 155MB ...
#      bxds2         (distance, fast_time) int16 155MB ...
#      bxds8         (distance, fast_time) int16 155MB ...
#      avg_velocity  float64 8B 33.62
#      velocity      (distance) float64 194kB 31.75 31.8 31.85 ... 35.46 35.4 35.34
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X12a
#      history:         Created on Sun Jan  4 16:47:29 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 855MB
#  Dimensions:       (distance: 22234, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 178kB 0.0 1.0 2.0 ... 2.223e+04 2.223e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 178kB ...
#      y             (distance) float64 178kB ...
#      h             (distance) float64 178kB ...
#      time          (distance) datetime64[ns] 178kB 2018-11-18T02:11:13.113800 ...
#      bxds7         (distance, fast_time) int16 142MB ...
#      bxds6         (distance, fast_time) int16 142MB ...
#      bxds5         (distance, fast_time) int16 142MB ...
#      bxds1         (distance, fast_time) int16 142MB ...
#      bxds8         (distance, fast_time) int16 142MB ...
#      bxds2         (distance, fast_time) int16 142MB ...
#      avg_velocity  float64 8B 36.45
#      velocity      (distance) float64 178kB 40.0 40.0 40.0 ... 36.97 36.97 36.9
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X13a
#      history:         Created on Sun Jan  4 16:48:02 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 940MB
#  Dimensions:       (distance: 24460, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 196kB 0.0 1.0 2.0 ... 2.446e+04 2.446e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 196kB ...
#      y             (distance) float64 196kB ...
#      h             (distance) float64 196kB ...
#      time          (distance) datetime64[ns] 196kB 2018-11-17T02:26:44.400900 ...
#      bxds5         (distance, fast_time) int16 157MB ...
#      bxds6         (distance, fast_time) int16 157MB ...
#      bxds7         (distance, fast_time) int16 157MB ...
#      bxds8         (distance, fast_time) int16 157MB ...
#      bxds2         (distance, fast_time) int16 157MB ...
#      bxds1         (distance, fast_time) int16 157MB ...
#      avg_velocity  float64 8B 33.97
#      velocity      (distance) float64 196kB 32.57 32.57 32.57 ... 36.5 36.5 36.5
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X14a
#      history:         Created on Sun Jan  4 16:48:32 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 888MB
#  Dimensions:       (distance: 23108, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 185kB 0.0 1.0 2.0 ... 2.311e+04 2.311e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 185kB ...
#      y             (distance) float64 185kB ...
#      h             (distance) float64 185kB ...
#      time          (distance) datetime64[ns] 185kB 2018-11-18T01:58:03.111400 ...
#      bxds7         (distance, fast_time) int16 148MB ...
#      bxds6         (distance, fast_time) int16 148MB ...
#      bxds5         (distance, fast_time) int16 148MB ...
#      bxds1         (distance, fast_time) int16 148MB ...
#      bxds8         (distance, fast_time) int16 148MB ...
#      bxds2         (distance, fast_time) int16 148MB ...
#      avg_velocity  float64 8B 34.49
#      velocity      (distance) float64 185kB 34.84 34.84 34.84 ... 37.31 37.31
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X15a
#      history:         Created on Sun Jan  4 16:49:05 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 884MB
#  Dimensions:       (distance: 22999, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 184kB 0.0 1.0 2.0 ... 2.3e+04 2.3e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 184kB ...
#      y             (distance) float64 184kB ...
#      h             (distance) float64 184kB ...
#      time          (distance) datetime64[ns] 184kB 2018-11-18T01:45:48.120800 ...
#      bxds5         (distance, fast_time) int16 147MB ...
#      bxds6         (distance, fast_time) int16 147MB ...
#      bxds7         (distance, fast_time) int16 147MB ...
#      bxds8         (distance, fast_time) int16 147MB ...
#      bxds2         (distance, fast_time) int16 147MB ...
#      bxds1         (distance, fast_time) int16 147MB ...
#      avg_velocity  float64 8B 37.09
#      velocity      (distance) float64 184kB 31.75 31.8 31.8 ... 33.17 33.22 33.22
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X17a
#      history:         Created on Sun Jan  4 16:49:36 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 914MB
#  Dimensions:       (distance: 23781, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 190kB 0.0 1.0 2.0 ... 2.378e+04 2.378e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 190kB ...
#      y             (distance) float64 190kB ...
#      h             (distance) float64 190kB ...
#      time          (distance) datetime64[ns] 190kB 2018-11-17T01:59:34.412400 ...
#      bxds1         (distance, fast_time) int16 152MB ...
#      bxds2         (distance, fast_time) int16 152MB ...
#      bxds8         (distance, fast_time) int16 152MB ...
#      bxds7         (distance, fast_time) int16 152MB ...
#      bxds6         (distance, fast_time) int16 152MB ...
#      bxds5         (distance, fast_time) int16 152MB ...
#      avg_velocity  float64 8B 33.97
#      velocity      (distance) float64 190kB 30.96 31.01 31.01 ... 32.0 31.95
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X18a
#      history:         Created on Sun Jan  4 16:50:08 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 878MB
#  Dimensions:       (distance: 22838, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 183kB 0.0 1.0 2.0 ... 2.284e+04 2.284e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 183kB ...
#      y             (distance) float64 183kB ...
#      h             (distance) float64 183kB ...
#      time          (distance) datetime64[ns] 183kB 2018-11-18T01:32:28.129000 ...
#      bxds5         (distance, fast_time) int16 146MB ...
#      bxds6         (distance, fast_time) int16 146MB ...
#      bxds7         (distance, fast_time) int16 146MB ...
#      bxds8         (distance, fast_time) int16 146MB ...
#      bxds2         (distance, fast_time) int16 146MB ...
#      bxds1         (distance, fast_time) int16 146MB ...
#      avg_velocity  float64 8B 33.1
#      velocity      (distance) float64 183kB 39.37 39.45 39.45 ... 33.96 33.9
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X19a
#      history:         Created on Sun Jan  4 16:50:44 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 909MB
#  Dimensions:       (distance: 23629, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 189kB 0.0 1.0 2.0 ... 2.363e+04 2.363e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 189kB ...
#      y             (distance) float64 189kB ...
#      h             (distance) float64 189kB ...
#      time          (distance) datetime64[ns] 189kB 2018-11-17T01:46:14.428000 ...
#      bxds5         (distance, fast_time) int16 151MB ...
#      bxds6         (distance, fast_time) int16 151MB ...
#      bxds7         (distance, fast_time) int16 151MB ...
#      bxds8         (distance, fast_time) int16 151MB ...
#      bxds2         (distance, fast_time) int16 151MB ...
#      bxds1         (distance, fast_time) int16 151MB ...
#      avg_velocity  float64 8B 32.37
#      velocity      (distance) float64 189kB 32.47 32.47 32.47 ... 34.72 34.72
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X20a
#      history:         Created on Sun Jan  4 16:51:16 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 863MB
#  Dimensions:       (distance: 22451, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 180kB 0.0 1.0 2.0 ... 2.245e+04 2.245e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 180kB ...
#      y             (distance) float64 180kB ...
#      h             (distance) float64 180kB ...
#      time          (distance) datetime64[ns] 180kB 2018-11-18T01:20:43.134200 ...
#      bxds2         (distance, fast_time) int16 144MB ...
#      bxds8         (distance, fast_time) int16 144MB ...
#      bxds1         (distance, fast_time) int16 144MB ...
#      bxds5         (distance, fast_time) int16 144MB ...
#      bxds6         (distance, fast_time) int16 144MB ...
#      bxds7         (distance, fast_time) int16 144MB ...
#      avg_velocity  float64 8B 37.42
#      velocity      (distance) float64 180kB 40.98 41.07 41.07 ... 39.29 39.22
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X21a
#      history:         Created on Sun Jan  4 16:51:48 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 929MB
#  Dimensions:       (distance: 24173, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 193kB 0.0 1.0 2.0 ... 2.417e+04 2.417e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 193kB ...
#      y             (distance) float64 193kB ...
#      h             (distance) float64 193kB ...
#      time          (distance) datetime64[ns] 193kB 2018-11-17T01:33:24.432400 ...
#      bxds7         (distance, fast_time) int16 155MB ...
#      bxds6         (distance, fast_time) int16 155MB ...
#      bxds5         (distance, fast_time) int16 155MB ...
#      bxds1         (distance, fast_time) int16 155MB ...
#      bxds8         (distance, fast_time) int16 155MB ...
#      bxds2         (distance, fast_time) int16 155MB ...
#      avg_velocity  float64 8B 36.08
#      velocity      (distance) float64 193kB 40.82 40.73 40.73 ... 39.06 39.06
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X22a
#      history:         Created on Sun Jan  4 16:52:50 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 893MB
#  Dimensions:       (distance: 23238, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 186kB 0.0 1.0 2.0 ... 2.324e+04 2.324e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 186kB ...
#      y             (distance) float64 186kB ...
#      h             (distance) float64 186kB ...
#      time          (distance) datetime64[ns] 186kB 2018-11-18T00:28:53.166800 ...
#      bxds6         (distance, fast_time) int16 149MB ...
#      bxds7         (distance, fast_time) int16 149MB ...
#      bxds5         (distance, fast_time) int16 149MB ...
#      bxds1         (distance, fast_time) int16 149MB ...
#      bxds2         (distance, fast_time) int16 149MB ...
#      bxds8         (distance, fast_time) int16 149MB ...
#      avg_velocity  float64 8B 36.31
#      velocity      (distance) float64 186kB 38.17 38.17 38.1 ... 37.95 38.02
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X23a
#      history:         Created on Sun Jan  4 16:53:23 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 944MB
#  Dimensions:       (distance: 24552, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 196kB 0.0 1.0 2.0 ... 2.455e+04 2.455e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 196kB ...
#      y             (distance) float64 196kB ...
#      h             (distance) float64 196kB ...
#      time          (distance) datetime64[ns] 196kB 2018-11-17T03:29:39.369000 ...
#      bxds6         (distance, fast_time) int16 157MB ...
#      bxds7         (distance, fast_time) int16 157MB ...
#      bxds5         (distance, fast_time) int16 157MB ...
#      bxds1         (distance, fast_time) int16 157MB ...
#      bxds2         (distance, fast_time) int16 157MB ...
#      bxds8         (distance, fast_time) int16 157MB ...
#      avg_velocity  float64 8B 35.84
#      velocity      (distance) float64 196kB 40.0 39.92 39.92 ... 38.31 38.31
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X24a
#      history:         Created on Sun Jan  4 16:53:54 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 879MB
#  Dimensions:       (distance: 22850, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 183kB 0.0 1.0 2.0 ... 2.285e+04 2.285e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 183kB ...
#      y             (distance) float64 183kB ...
#      h             (distance) float64 183kB ...
#      time          (distance) datetime64[ns] 183kB 2018-11-18T00:17:03.173400 ...
#      bxds6         (distance, fast_time) int16 146MB ...
#      bxds7         (distance, fast_time) int16 146MB ...
#      bxds5         (distance, fast_time) int16 146MB ...
#      bxds1         (distance, fast_time) int16 146MB ...
#      bxds2         (distance, fast_time) int16 146MB ...
#      bxds8         (distance, fast_time) int16 146MB ...
#      avg_velocity  float64 8B 38.08
#      velocity      (distance) float64 183kB 36.9 36.97 36.97 ... 36.1 36.1 36.1
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X25a
#      history:         Created on Sun Jan  4 16:54:28 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 907MB
#  Dimensions:       (distance: 23587, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 189kB 0.0 1.0 2.0 ... 2.358e+04 2.359e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 189kB ...
#      y             (distance) float64 189kB ...
#      h             (distance) float64 189kB ...
#      time          (distance) datetime64[ns] 189kB 2018-11-17T03:42:44.359500 ...
#      bxds1         (distance, fast_time) int16 151MB ...
#      bxds8         (distance, fast_time) int16 151MB ...
#      bxds2         (distance, fast_time) int16 151MB ...
#      bxds7         (distance, fast_time) int16 151MB ...
#      bxds6         (distance, fast_time) int16 151MB ...
#      bxds5         (distance, fast_time) int16 151MB ...
#      avg_velocity  float64 8B 33.22
#      velocity      (distance) float64 189kB 32.57 32.52 32.52 ... 35.09 35.09
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X26a
#      history:         Created on Sun Jan  4 16:55:01 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 877MB
#  Dimensions:       (distance: 22821, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 183kB 0.0 1.0 2.0 ... 2.282e+04 2.282e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 183kB ...
#      y             (distance) float64 183kB ...
#      h             (distance) float64 183kB ...
#      time          (distance) datetime64[ns] 183kB 2018-11-18T03:10:13.076400 ...
#      bxds5         (distance, fast_time) int16 146MB ...
#      bxds6         (distance, fast_time) int16 146MB ...
#      bxds7         (distance, fast_time) int16 146MB ...
#      bxds8         (distance, fast_time) int16 146MB ...
#      bxds2         (distance, fast_time) int16 146MB ...
#      bxds1         (distance, fast_time) int16 146MB ...
#      avg_velocity  float64 8B 36.81
#      velocity      (distance) float64 183kB 41.15 41.15 41.15 ... 34.13 34.13
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X27a
#      history:         Created on Sun Jan  4 16:55:35 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 917MB
#  Dimensions:       (distance: 23859, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 191kB 0.0 1.0 2.0 ... 2.386e+04 2.386e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 191kB ...
#      y             (distance) float64 191kB ...
#      h             (distance) float64 191kB ...
#      time          (distance) datetime64[ns] 191kB 2018-11-17T03:55:59.345200 ...
#      bxds1         (distance, fast_time) int16 153MB ...
#      bxds8         (distance, fast_time) int16 153MB ...
#      bxds2         (distance, fast_time) int16 153MB ...
#      bxds7         (distance, fast_time) int16 153MB ...
#      bxds6         (distance, fast_time) int16 153MB ...
#      bxds5         (distance, fast_time) int16 153MB ...
#      avg_velocity  float64 8B 36.54
#      velocity      (distance) float64 191kB 38.76 38.76 38.83 ... 36.83 36.9 36.9
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X28a
#      history:         Created on Sun Jan  4 16:56:38 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 862MB
#  Dimensions:       (distance: 22424, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 179kB 0.0 1.0 2.0 ... 2.242e+04 2.242e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 179kB ...
#      y             (distance) float64 179kB ...
#      h             (distance) float64 179kB ...
#      time          (distance) datetime64[ns] 179kB 2018-11-18T03:22:23.072900 ...
#      bxds1         (distance, fast_time) int16 144MB ...
#      bxds2         (distance, fast_time) int16 144MB ...
#      bxds8         (distance, fast_time) int16 144MB ...
#      bxds7         (distance, fast_time) int16 144MB ...
#      bxds6         (distance, fast_time) int16 144MB ...
#      bxds5         (distance, fast_time) int16 144MB ...
#      avg_velocity  float64 8B 36.17
#      velocity      (distance) float64 179kB 34.25 34.19 34.13 ... 37.66 37.74
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X29a
#      history:         Created on Sun Jan  4 16:57:10 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 889MB
#  Dimensions:       (distance: 23113, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 185kB 0.0 1.0 2.0 ... 2.311e+04 2.311e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 185kB ...
#      y             (distance) float64 185kB ...
#      h             (distance) float64 185kB ...
#      time          (distance) datetime64[ns] 185kB 2018-11-17T04:08:19.338500 ...
#      bxds6         (distance, fast_time) int16 148MB ...
#      bxds7         (distance, fast_time) int16 148MB ...
#      bxds5         (distance, fast_time) int16 148MB ...
#      bxds1         (distance, fast_time) int16 148MB ...
#      bxds8         (distance, fast_time) int16 148MB ...
#      bxds2         (distance, fast_time) int16 148MB ...
#      avg_velocity  float64 8B 35.83
#      velocity      (distance) float64 185kB 25.91 25.91 25.91 ... 40.4 40.32
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X30a
#      history:         Created on Sun Jan  4 16:57:41 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 854MB
#  Dimensions:       (distance: 22203, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 178kB 0.0 1.0 2.0 ... 2.22e+04 2.22e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 178kB ...
#      y             (distance) float64 178kB ...
#      h             (distance) float64 178kB ...
#      time          (distance) datetime64[ns] 178kB 2018-11-18T03:34:53.066800 ...
#      bxds6         (distance, fast_time) int16 142MB ...
#      bxds7         (distance, fast_time) int16 142MB ...
#      bxds5         (distance, fast_time) int16 142MB ...
#      bxds1         (distance, fast_time) int16 142MB ...
#      bxds8         (distance, fast_time) int16 142MB ...
#      bxds2         (distance, fast_time) int16 142MB ...
#      avg_velocity  float64 8B 34.69
#      velocity      (distance) float64 178kB 40.0 39.92 39.92 ... 33.67 33.67
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X31a
#      history:         Created on Sun Jan  4 16:58:13 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 885MB
#  Dimensions:       (distance: 23028, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 184kB 0.0 1.0 2.0 ... 2.303e+04 2.303e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 184kB ...
#      y             (distance) float64 184kB ...
#      h             (distance) float64 184kB ...
#      time          (distance) datetime64[ns] 184kB 2018-11-17T04:21:19.335000 ...
#      bxds2         (distance, fast_time) int16 147MB ...
#      bxds8         (distance, fast_time) int16 147MB ...
#      bxds1         (distance, fast_time) int16 147MB ...
#      bxds5         (distance, fast_time) int16 147MB ...
#      bxds6         (distance, fast_time) int16 147MB ...
#      bxds7         (distance, fast_time) int16 147MB ...
#      avg_velocity  float64 8B 38.19
#      velocity      (distance) float64 184kB 40.16 40.16 40.08 ... 38.39 38.46
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X32a
#      history:         Created on Sun Jan  4 16:58:44 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 852MB
#  Dimensions:       (distance: 22161, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 177kB 0.0 1.0 2.0 ... 2.216e+04 2.216e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 177kB ...
#      y             (distance) float64 177kB ...
#      h             (distance) float64 177kB ...
#      time          (distance) datetime64[ns] 177kB 2018-11-18T03:47:23.060400 ...
#      bxds1         (distance, fast_time) int16 142MB ...
#      bxds8         (distance, fast_time) int16 142MB ...
#      bxds2         (distance, fast_time) int16 142MB ...
#      bxds6         (distance, fast_time) int16 142MB ...
#      bxds7         (distance, fast_time) int16 142MB ...
#      bxds5         (distance, fast_time) int16 142MB ...
#      avg_velocity  float64 8B 35.74
#      velocity      (distance) float64 177kB 37.31 37.24 37.24 ... 39.68 39.68
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X33a
#      history:         Created on Sun Jan  4 16:59:15 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 866MB
#  Dimensions:       (distance: 22513, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 180kB 0.0 1.0 2.0 ... 2.251e+04 2.251e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 180kB ...
#      y             (distance) float64 180kB ...
#      h             (distance) float64 180kB ...
#      time          (distance) datetime64[ns] 180kB 2018-11-17T04:32:59.328200 ...
#      bxds7         (distance, fast_time) int16 144MB ...
#      bxds6         (distance, fast_time) int16 144MB ...
#      bxds5         (distance, fast_time) int16 144MB ...
#      bxds1         (distance, fast_time) int16 144MB ...
#      bxds2         (distance, fast_time) int16 144MB ...
#      bxds8         (distance, fast_time) int16 144MB ...
#      avg_velocity  float64 8B 33.85
#      velocity      (distance) float64 180kB 29.94 29.98 29.98 ... 35.52 35.59
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X34a
#      history:         Created on Sun Jan  4 16:59:46 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 855MB
#  Dimensions:       (distance: 22229, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 178kB 0.0 1.0 2.0 ... 2.223e+04 2.223e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 178kB ...
#      y             (distance) float64 178kB ...
#      h             (distance) float64 178kB ...
#      time          (distance) datetime64[ns] 178kB 2018-11-18T04:00:43.049600 ...
#      bxds5         (distance, fast_time) int16 142MB ...
#      bxds6         (distance, fast_time) int16 142MB ...
#      bxds7         (distance, fast_time) int16 142MB ...
#      bxds8         (distance, fast_time) int16 142MB ...
#      bxds2         (distance, fast_time) int16 142MB ...
#      bxds1         (distance, fast_time) int16 142MB ...
#      avg_velocity  float64 8B 35.85
#      velocity      (distance) float64 178kB 34.84 34.9 34.9 ... 37.24 37.24 37.17
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X35a
#      history:         Created on Sun Jan  4 17:00:21 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 845MB
#  Dimensions:       (distance: 21988, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 176kB 0.0 1.0 2.0 ... 2.199e+04 2.199e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 176kB ...
#      y             (distance) float64 176kB ...
#      h             (distance) float64 176kB ...
#      time          (distance) datetime64[ns] 176kB 2018-11-18T04:12:48.046200 ...
#      bxds5         (distance, fast_time) int16 141MB ...
#      bxds6         (distance, fast_time) int16 141MB ...
#      bxds7         (distance, fast_time) int16 141MB ...
#      bxds8         (distance, fast_time) int16 141MB ...
#      bxds2         (distance, fast_time) int16 141MB ...
#      bxds1         (distance, fast_time) int16 141MB ...
#      avg_velocity  float64 8B 35.46
#      velocity      (distance) float64 176kB 40.65 40.65 40.73 ... 35.78 35.84
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0e/X37a
#      history:         Created on Sun Jan  4 17:00:53 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 1GB
#  Dimensions:       (distance: 29324, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 235kB 0.0 1.0 2.0 ... 2.932e+04 2.932e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 235kB ...
#      y             (distance) float64 235kB ...
#      h             (distance) float64 235kB ...
#      time          (distance) datetime64[ns] 235kB 2018-11-25T03:55:49.846200 ...
#      bxds5         (distance, fast_time) int16 188MB ...
#      bxds6         (distance, fast_time) int16 188MB ...
#      bxds7         (distance, fast_time) int16 188MB ...
#      bxds2         (distance, fast_time) int16 188MB ...
#      bxds8         (distance, fast_time) int16 188MB ...
#      bxds1         (distance, fast_time) int16 188MB ...
#      avg_velocity  float64 8B 37.36
#      velocity      (distance) float64 235kB 36.63 36.63 36.56 ... 38.1 38.1 38.17
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0g/Y22a
#      history:         Created on Tue Jan  6 14:15:54 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 1GB
#  Dimensions:       (distance: 37942, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 304kB 0.0 1.0 2.0 ... 3.794e+04 3.794e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 304kB ...
#      y             (distance) float64 304kB ...
#      h             (distance) float64 304kB ...
#      time          (distance) datetime64[ns] 304kB 2018-11-25T05:16:39.794900 ...
#      bxds2         (distance, fast_time) int16 243MB ...
#      bxds8         (distance, fast_time) int16 243MB ...
#      bxds1         (distance, fast_time) int16 243MB ...
#      bxds5         (distance, fast_time) int16 243MB ...
#      bxds7         (distance, fast_time) int16 243MB ...
#      bxds6         (distance, fast_time) int16 243MB ...
#      avg_velocity  float64 8B 43.36
#      velocity      (distance) float64 304kB 40.32 40.24 40.16 ... 42.46 42.37
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0g/Y23a
#      history:         Created on Tue Jan  6 14:16:45 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 1GB
#  Dimensions:       (distance: 28459, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 228kB 0.0 1.0 2.0 ... 2.846e+04 2.846e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 228kB ...
#      y             (distance) float64 228kB ...
#      h             (distance) float64 228kB ...
#      time          (distance) datetime64[ns] 228kB 2018-11-25T03:42:29.852000 ...
#      bxds8         (distance, fast_time) int16 182MB ...
#      bxds2         (distance, fast_time) int16 182MB ...
#      bxds1         (distance, fast_time) int16 182MB ...
#      bxds5         (distance, fast_time) int16 182MB ...
#      bxds6         (distance, fast_time) int16 182MB ...
#      bxds7         (distance, fast_time) int16 182MB ...
#      avg_velocity  float64 8B 42.16
#      velocity      (distance) float64 228kB 41.32 41.32 41.24 ... 43.76 43.67
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0g/Y24a
#      history:         Created on Tue Jan  6 14:18:11 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 1GB
#  Dimensions:       (distance: 29514, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 236kB 0.0 1.0 2.0 ... 2.951e+04 2.951e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 236kB ...
#      y             (distance) float64 236kB ...
#      h             (distance) float64 236kB ...
#      time          (distance) datetime64[ns] 236kB 2018-11-25T04:13:54.834100 ...
#      bxds7         (distance, fast_time) int16 189MB ...
#      bxds6         (distance, fast_time) int16 189MB ...
#      bxds5         (distance, fast_time) int16 189MB ...
#      bxds1         (distance, fast_time) int16 189MB ...
#      bxds2         (distance, fast_time) int16 189MB ...
#      bxds8         (distance, fast_time) int16 189MB ...
#      avg_velocity  float64 8B 43.4
#      velocity      (distance) float64 236kB 44.44 44.44 44.44 ... 44.84 44.84
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0g/Y25a
#      history:         Created on Tue Jan  6 14:19:11 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 1GB
#  Dimensions:       (distance: 29264, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 234kB 0.0 1.0 2.0 ... 2.926e+04 2.926e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 234kB ...
#      y             (distance) float64 234kB ...
#      h             (distance) float64 234kB ...
#      time          (distance) datetime64[ns] 234kB 2018-11-25T03:27:34.859200 ...
#      bxds1         (distance, fast_time) int16 187MB ...
#      bxds2         (distance, fast_time) int16 187MB ...
#      bxds8         (distance, fast_time) int16 187MB ...
#      bxds6         (distance, fast_time) int16 187MB ...
#      bxds7         (distance, fast_time) int16 187MB ...
#      bxds5         (distance, fast_time) int16 187MB ...
#      avg_velocity  float64 8B 36.81
#      velocity      (distance) float64 234kB 32.15 32.1 32.1 ... 38.1 38.1 38.02
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0g/Y26a
#      history:         Created on Tue Jan  6 14:20:10 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 1GB
#  Dimensions:       (distance: 29021, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 232kB 0.0 1.0 2.0 ... 2.902e+04 2.902e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 232kB ...
#      y             (distance) float64 232kB ...
#      h             (distance) float64 232kB ...
#      time          (distance) datetime64[ns] 232kB 2018-11-25T04:26:54.823800 ...
#      bxds5         (distance, fast_time) int16 186MB ...
#      bxds6         (distance, fast_time) int16 186MB ...
#      bxds7         (distance, fast_time) int16 186MB ...
#      bxds2         (distance, fast_time) int16 186MB ...
#      bxds8         (distance, fast_time) int16 186MB ...
#      bxds1         (distance, fast_time) int16 186MB ...
#      avg_velocity  float64 8B 35.18
#      velocity      (distance) float64 232kB 35.59 35.59 35.52 ... 33.33 33.33
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0g/Y27a
#      history:         Created on Tue Jan  6 14:21:13 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 1GB
#  Dimensions:       (distance: 29996, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 240kB 0.0 1.0 2.0 ... 2.999e+04 3e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 240kB ...
#      y             (distance) float64 240kB ...
#      h             (distance) float64 240kB ...
#      time          (distance) datetime64[ns] 240kB 2018-11-25T03:10:49.869800 ...
#      bxds1         (distance, fast_time) int16 192MB ...
#      bxds2         (distance, fast_time) int16 192MB ...
#      bxds8         (distance, fast_time) int16 192MB ...
#      bxds6         (distance, fast_time) int16 192MB ...
#      bxds7         (distance, fast_time) int16 192MB ...
#      bxds5         (distance, fast_time) int16 192MB ...
#      avg_velocity  float64 8B 38.46
#      velocity      (distance) float64 240kB 41.49 41.41 41.32 ... 41.32 41.32
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0g/Y28a
#      history:         Created on Tue Jan  6 14:22:12 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 1GB
#  Dimensions:       (distance: 29250, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 234kB 0.0 1.0 2.0 ... 2.925e+04 2.925e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 234kB ...
#      y             (distance) float64 234kB ...
#      h             (distance) float64 234kB ...
#      time          (distance) datetime64[ns] 234kB 2018-11-25T01:02:09.943100 ...
#      bxds1         (distance, fast_time) int16 187MB ...
#      bxds8         (distance, fast_time) int16 187MB ...
#      bxds2         (distance, fast_time) int16 187MB ...
#      bxds6         (distance, fast_time) int16 187MB ...
#      bxds7         (distance, fast_time) int16 187MB ...
#      bxds5         (distance, fast_time) int16 187MB ...
#      avg_velocity  float64 8B 37.5
#      velocity      (distance) float64 234kB 37.31 37.31 37.31 ... 39.06 39.06
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0g/Y29a
#      history:         Created on Tue Jan  6 14:23:24 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 1GB
#  Dimensions:       (distance: 37695, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 302kB 0.0 1.0 2.0 ... 3.769e+04 3.769e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 302kB ...
#      y             (distance) float64 302kB ...
#      h             (distance) float64 302kB ...
#      time          (distance) datetime64[ns] 302kB 2018-11-24T23:57:54.973000 ...
#      bxds5         (distance, fast_time) int16 241MB ...
#      bxds7         (distance, fast_time) int16 241MB ...
#      bxds6         (distance, fast_time) int16 241MB ...
#      bxds2         (distance, fast_time) int16 241MB ...
#      bxds8         (distance, fast_time) int16 241MB ...
#      bxds1         (distance, fast_time) int16 241MB ...
#      avg_velocity  float64 8B 39.47
#      velocity      (distance) float64 302kB 40.49 40.49 40.4 ... 38.99 38.91
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0g/Y30a
#      history:         Created on Tue Jan  6 14:24:27 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 1GB
#  Dimensions:       (distance: 30837, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 247kB 0.0 1.0 2.0 ... 3.084e+04 3.084e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 247kB ...
#      y             (distance) float64 247kB ...
#      h             (distance) float64 247kB ...
#      time          (distance) datetime64[ns] 247kB 2018-11-25T01:16:49.935400 ...
#      bxds7         (distance, fast_time) int16 197MB ...
#      bxds6         (distance, fast_time) int16 197MB ...
#      bxds5         (distance, fast_time) int16 197MB ...
#      bxds1         (distance, fast_time) int16 197MB ...
#      bxds8         (distance, fast_time) int16 197MB ...
#      bxds2         (distance, fast_time) int16 197MB ...
#      avg_velocity  float64 8B 37.84
#      velocity      (distance) float64 247kB 39.06 39.06 39.06 ... 38.91 38.91
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0g/Y31a
#      history:         Created on Tue Jan  6 14:25:50 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 1GB
#  Dimensions:       (distance: 30035, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 240kB 0.0 1.0 2.0 ... 3.003e+04 3.003e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 240kB ...
#      y             (distance) float64 240kB ...
#      h             (distance) float64 240kB ...
#      time          (distance) datetime64[ns] 240kB 2018-11-25T02:16:59.899000 ...
#      bxds5         (distance, fast_time) int16 192MB ...
#      bxds6         (distance, fast_time) int16 192MB ...
#      bxds7         (distance, fast_time) int16 192MB ...
#      bxds2         (distance, fast_time) int16 192MB ...
#      bxds8         (distance, fast_time) int16 192MB ...
#      bxds1         (distance, fast_time) int16 192MB ...
#      avg_velocity  float64 8B 37.54
#      velocity      (distance) float64 240kB 37.59 37.59 37.59 ... 37.38 37.31
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0g/Y32a
#      history:         Created on Tue Jan  6 14:26:56 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 1GB
#  Dimensions:       (distance: 31073, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 249kB 0.0 1.0 2.0 ... 3.107e+04 3.107e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 249kB ...
#      y             (distance) float64 249kB ...
#      h             (distance) float64 249kB ...
#      time          (distance) datetime64[ns] 249kB 2018-11-25T01:32:14.923500 ...
#      bxds8         (distance, fast_time) int16 199MB ...
#      bxds2         (distance, fast_time) int16 199MB ...
#      bxds1         (distance, fast_time) int16 199MB ...
#      bxds5         (distance, fast_time) int16 199MB ...
#      bxds7         (distance, fast_time) int16 199MB ...
#      bxds6         (distance, fast_time) int16 199MB ...
#      avg_velocity  float64 8B 40.35
#      velocity      (distance) float64 249kB 37.17 37.17 37.17 ... 37.95 38.02
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0g/Y33a
#      history:         Created on Tue Jan  6 14:28:07 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 1GB
#  Dimensions:       (distance: 30211, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 242kB 0.0 1.0 2.0 ... 3.021e+04 3.021e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 242kB ...
#      y             (distance) float64 242kB ...
#      h             (distance) float64 242kB ...
#      time          (distance) datetime64[ns] 242kB 2018-11-25T02:02:07.909000 ...
#      bxds5         (distance, fast_time) int16 193MB ...
#      bxds6         (distance, fast_time) int16 193MB ...
#      bxds7         (distance, fast_time) int16 193MB ...
#      bxds2         (distance, fast_time) int16 193MB ...
#      bxds8         (distance, fast_time) int16 193MB ...
#      bxds1         (distance, fast_time) int16 193MB ...
#      avg_velocity  float64 8B 40.44
#      velocity      (distance) float64 242kB 41.49 41.41 41.32 ... 36.7 36.7 36.76
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0g/Y34a
#      history:         Created on Tue Jan  6 14:29:22 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620,
#  <xarray.Dataset> Size: 1GB
#  Dimensions:       (distance: 28968, fast_time: 3200)
#  Coordinates:
#    * distance      (distance) float64 232kB 0.0 1.0 2.0 ... 2.897e+04 2.897e+04
#    * fast_time     (fast_time) timedelta64[ns] 26kB 00:00:00 ... 00:00:00.0000...
#  Data variables:
#      x             (distance) float64 232kB ...
#      y             (distance) float64 232kB ...
#      h             (distance) float64 232kB ...
#      time          (distance) datetime64[ns] 232kB 2018-11-25T01:47:04.918200 ...
#      bxds7         (distance, fast_time) int16 185MB ...
#      bxds6         (distance, fast_time) int16 185MB ...
#      bxds5         (distance, fast_time) int16 185MB ...
#      bxds1         (distance, fast_time) int16 185MB ...
#      bxds2         (distance, fast_time) int16 185MB ...
#      bxds8         (distance, fast_time) int16 185MB ...
#      avg_velocity  float64 8B 37.62
#      velocity      (distance) float64 232kB 40.82 40.82 40.73 ... 36.63 36.63
#  Attributes: (12/13)
#      transect_id:     D2DG/IBH0g/Y35a
#      history:         Created on Tue Jan  6 14:30:43 2026 by Duncan A. Young
#      funding:         KOPRI/K-ROUTE
#      expedition:      KRT2
#      platform:        AS-350 helicopter
#      radar:           HeRa
#      ...              ...
#      sample_rate_hz:  50000000.0
#      chirp_start_hz:  17500000.0
#      chirp_end_hz:    2500000.0
#      lo_gain_dbm:     82.7
#      high_gain_dbm:   128.7
#      reference:       http://doi.org/10.26153/tsw/11620]

# %%
### Figure 4 ###
# Doppler width map with velocity scaling for 2018-2019, 2016-2017, and difference map
# with comparison to satellite lake outlines

# Plot plan view comparison, scaled by velocity
def common_panel_elements(ax, plot_dict, rad_vel):
    """
    Plot doppler width and lake outline map view.
    """

    bbox = [650000,-1475000,680000,-1430000] #David_SGL2_full extent

    # Remove borders
    ax.patch.set_facecolor("none")
    for spine in ax.spines.values():
        spine.set_visible(False)
    ax.set_xticks([])
    ax.set_yticks([])

    # Plot scaled widths
    velocities = [rad['velocity'] for rad in rad_vel[:]]
    for x_center_list, y_center_list, plotting, velocity in zip(plot_dict['x_centers'], plot_dict['y_centers'], plot_dict['ridge_params_list'], velocities):
        width = [rp['right'] - rp['left'] for rp in plotting]
        scaled_width = [w * v for w,v in zip(width,velocity)]  # Scale by velocity to get doppler width
        #print(min(scaled_width), max(scaled_width))
        cb = ax.scatter(x_center_list, y_center_list, c=scaled_width, cmap='viridis', s=30, zorder=4,vmin=0,vmax=900)

    # Add colorbar
    k_cbar_anchor = (0,0)
    cbbox = inset_axes(ax, width=3,height=1,
                    bbox_to_anchor=k_cbar_anchor,
                    bbox_transform=ax.transAxes, loc="center left")
    [cbbox.spines[k].set_visible(False) for k in cbbox.spines]
    cbbox.tick_params(
        axis = 'both',
        left = False,
        top = False,
        right = False,
        bottom = False,
        labelleft = False,
        labeltop = False,
        labelright = False,
        labelbottom = False
    )

    cbbox.set_facecolor([0,0,0,0.9])

    cbaxes = inset_axes(cbbox, '92%', '20%', loc = 'center')
    cbar=fig.colorbar(cb,cax=cbaxes, orientation='horizontal',extend='max') #make colorbar
    cbar.outline.set_edgecolor('white')
    cbar.outline.set_linewidth(1)
    cbar.ax.tick_params(labelsize=14, color='white', labelcolor='white')
    cbar.set_label(r"Doppler Width [Hz]", fontsize=15, color='white')
    cbar.ax.xaxis.set_label_position('top')

    cbar.ax.minorticks_on()

    ax.set_xlim(bbox[0],bbox[2])
    ax.set_ylim(bbox[1],bbox[3])
    
    scalebar = AnchoredSizeBar(ax.transData, 5000, '5 km', 'upper left', pad=1.5, color='black', frameon=False, size_vertical=300, fontproperties={'size': 14})
    ax.add_artist(scalebar)

    # Glacial flow arrow
    ax.annotate(
    '',
    xy=(659000, -1436000),      # Tip
    xytext=(664000, -1431000),  # Tail
    arrowprops=dict(
        arrowstyle='-|>',       
        color='black',
        lw=2,
        mutation_scale=20 ,     
    ),
    transform=ps71_projection,
    zorder=10
    )
    ax.text(664000, -1432000, ' Ice Flow\nDirection',
        fontsize=14, color='black', ha='left', va='center',zorder=10)

    return ax


# Load evolving outlines
evolving_outlines = gpd.read_file(f'{evolving_path}/David_s1.geojson')

# Load DDInSAR outlines
path2 = f'{DDInSAR_path}/David2.shp'
path2_1 = f'{DDInSAR_path}/David2-1.shp'

DDInSAR_outlines = []
for path in [path2, path2_1]:
    sf = shapefile.Reader(path)
    for shape in sf.shapes():
        points = shape.points
        pts_xy = ll2xy([p[0] for p in points], [p[1] for p in points])
        x, y = pts_xy

        DDInSAR_outlines.append((x, y))

# %%
times = evolving_outlines["mid_pt_datetime"]
# Find index of time closest to Jan 25 2017 and Nov 20 2018
target_time_1617 = np.datetime64('2017-01-25T00:00:00')
target_time_1819 = np.datetime64('2018-11-20T00:00:00')

idx_1617 = np.argmin(np.abs(times - target_time_1617))
idx_1819 = np.argmin(np.abs(times - target_time_1819))
print(times[idx_1617], times[idx_1819])

# Plot outlines function
def plot_outlines(ax, evolving_outlines, DDInSAR_outlines, idx_1617, idx_1819):
    """Plot outlines for radar, DDInSAR, and Altimetry. Return colors associated with each"""
    colors = []
    # Plot evolving outlines
    for index in [idx_1617, idx_1819]:
        outline = evolving_outlines['geometry'][index]
        time = t_num[index]
        color = cmap(norm(time))
        x_evolve, y_evolve = outline.exterior.xy
        ax.plot(x_evolve, y_evolve, color=color, zorder=5, linewidth=2.5)
        colors.append(color)

    # Plot DDInSAR outlines
    color_DDInSAR = 'black'
    for i, (x, y) in enumerate(DDInSAR_outlines):
        ax.plot(x, y, color=color_DDInSAR, linewidth=2.5, zorder=5)
    colors.append(color_DDInSAR)

    # Plot radar outlines
    color_radar = 'white'
    for x, y in zip(xs_lake, ys_lake):
        ax.plot(x, y, color=color_radar, linewidth=2.5, zorder=5)
    colors.append(color_radar)
    
    # Label radar lakes A, B, C
    ax.annotate('A', xy=(657000, -1446000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection,zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])
    ax.annotate('B', xy=(664200, -1454000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection, zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])
    ax.annotate('C', xy=(668500, -1458000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection,zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])

    return colors
# Out:
# 2017-01-01 00:00:00 2019-01-01 00:00:00

# %%
ps71_projection = ccrs.Stereographic(central_latitude=-90, central_longitude=0, true_scale_latitude=-71)
fig, axs = plt.subplots(1,3, figsize=(17,8), subplot_kw={'projection': ps71_projection})
(ax1, ax2, ax3) = axs.flatten()

# Convert datetimes → numeric (float seconds)
t_num = np.array(times.astype("int64"))  # nanoseconds since epoch

# Normalize to 0–1 range for the colormap
norm = colors.Normalize(vmin=t_num.min(), vmax=t_num.max())
cmap = cm.get_cmap("inferno")
sm = cm.ScalarMappable(norm=norm, cmap=cmap)


## AX1 ##
common_panel_elements(ax1, plotting_dict, offset_video_radargrams_1617)
colors_plotted = plot_outlines(ax1, evolving_outlines, DDInSAR_outlines, idx_1617, idx_1819)

k_cbar_anchor = (0,0.08) # Bottom right of ax1
cbbox = inset_axes(ax1, width=3.8,height=1.2,
                bbox_to_anchor=k_cbar_anchor,
                bbox_transform=ax1.transAxes, loc="lower left")
[cbbox.spines[k].set_visible(False) for k in cbbox.spines]
cbbox.tick_params(
    axis = 'both',
    left = False,
    top = False,
    right = False,
    bottom = False,
    labelleft = False,
    labeltop = False,
    labelright = False,
    labelbottom = False
)
cbbox.set_facecolor([0,0,0,0.9])
handles = [
    Line2D([0], [0], color=colors_plotted[0], lw=4, label='Jan 01 2017 Evolving Outline'),
    Line2D([0], [0], color=colors_plotted[1], lw=4, label='Jan 01 2019 Evolving Outline'),
    Line2D([0], [0], color=colors_plotted[2], lw=4, label='???? DDInSAR Outline'),
    Line2D([0], [0], color=colors_plotted[3], lw=4, label='2018\u20132019 Radar Oultine'),
]

# Add legend directly to cbbox
legend = cbbox.legend(
    handles=handles,
    loc='center left',          # center vertically, left horizontally
    bbox_to_anchor=(0.0, 0.5), # tweak horizontal position
    frameon=False,
    fontsize=14,
    labelcolor='white'
)

# Make sure text is white
for text in legend.get_texts():
    text.set_color('white')




## AX2 ##
common_panel_elements(ax2, plotting_dict_1819, offset_video_radargrams_1819)
plot_outlines(ax2, evolving_outlines, DDInSAR_outlines, idx_1617, idx_1819)


## AX3 ##
# Remove borders
ax3.patch.set_facecolor("none")
for spine in ax3.spines.values():
    spine.set_visible(False)
ax3.set_xticks([])
ax3.set_yticks([])


# Add colorbar
k_cbar_anchor = (0,0)
cbbox = inset_axes(ax3, width=3.5,height=1,
                bbox_to_anchor=k_cbar_anchor,
                bbox_transform=ax3.transAxes, loc="center left")
[cbbox.spines[k].set_visible(False) for k in cbbox.spines]
cbbox.tick_params(
    axis = 'both',
    left = False,
    top = False,
    right = False,
    bottom = False,
    labelleft = False,
    labeltop = False,
    labelright = False,
    labelbottom = False
)
cbbox.set_facecolor([0,0,0,0.9])

cb = ax3.scatter(matched_coords[:,0], matched_coords[:,1], c=ridge_diff_velocity_scaled, cmap='seismic', s=30, zorder=4,vmin=-600,vmax=600)
cbaxes = inset_axes(cbbox, '92%', '20%', loc = 'center')
cbar=fig.colorbar(cb,cax=cbaxes, orientation='horizontal') #make colorbar
cbar.outline.set_edgecolor('white')
cbar.outline.set_linewidth(1)
cbar.ax.tick_params(labelsize=14, color='white', labelcolor='white')
cbar.set_label(r"2018-2019 $-$ 2016-2017", fontsize=15, color='white')
cbar.ax.xaxis.set_label_position('top')

cbar.ax.minorticks_on()

scalebar = AnchoredSizeBar(ax3.transData, 5000, '5 km', 'upper left', pad=1.5, color='black', frameon=False, size_vertical=300, fontproperties={'size': 14})
ax3.add_artist(scalebar)

# Glacial flow arrow
ax3.annotate(
'',
xy=(659000, -1436000),      # Tip
xytext=(664000, -1431000),  # Tail
arrowprops=dict(
    arrowstyle='-|>',       
    color='black',
    lw=2,
    mutation_scale=20 ,     
),
transform=ps71_projection,
zorder=10
)
ax3.text(664000, -1432000, ' Ice Flow\nDirection',
    fontsize=14, color='black', ha='left', va='center',zorder=10)

bbox = [650000,-1475000,680000,-1430000] #David_SGL2_full extent
ax3.set_xlim(bbox[0],bbox[2])
ax3.set_ylim(bbox[1],bbox[3])

plot_outlines(ax3, evolving_outlines, DDInSAR_outlines, idx_1617, idx_1819)

# Set background gainsboro
fig.patch.set_facecolor('gainsboro')

fig.savefig(os.path.join(outdir, 'Figure4.png'), dpi=300, bbox_inches='tight')
# Out:
# /tmp/ipykernel_2146/4157616866.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap("inferno")

# %%
## Figure S2 ##
# Velocity plots

# Plot velocities
ps71_projection = ccrs.Stereographic(central_latitude=-90, central_longitude=0, true_scale_latitude=-71)
fig, (ax,ax2) = plt.subplots(1,2,figsize=(12,8), subplot_kw={'projection': ps71_projection})

scalebar = AnchoredSizeBar(ax.transData, 5000, '5 km', 'upper left', pad=1.5, color='black', frameon=False, size_vertical=300, fontproperties={'size': 14})
ax.add_artist(scalebar)

#bbox = [650000,-1475000,680000,-1430000] #David_SGL2_full extent
# Glacial Flow Direction Arrow
ax.annotate(
    '',
    xy=(659000, -1436000),      # arrow tip (downstream)
    xytext=(664000, -1431000),  # arrow tail
    arrowprops=dict(
        arrowstyle='-|>',       # filled arrow head
        color='black',
        lw=2,
        mutation_scale=20 ,      # controls head size
    ),
    transform=ps71_projection,
    zorder=10
)

ax.text(664000, -1432000, ' Ice Flow\nDirection',
        fontsize=14, color='black', ha='left', va='center',zorder=10)

bbox = [650000,-1475000,680000,-1430000] #David_SGL2_full extent

# Remove borders
ax.patch.set_facecolor("none")
for spine in ax.spines.values():
    spine.set_visible(False)
ax.set_xticks([])
ax.set_yticks([])

for x, y in zip(xs_lake, ys_lake):
    ax.plot(x, y, color='white', linewidth=2.5, zorder=5)

# Add colorbar
k_cbar_anchor = (0,0)
cbbox = inset_axes(ax, width=3,height=1,
                bbox_to_anchor=k_cbar_anchor,
                bbox_transform=ax.transAxes, loc="center left")
[cbbox.spines[k].set_visible(False) for k in cbbox.spines]
cbbox.tick_params(
    axis = 'both',
    left = False,
    top = False,
    right = False,
    bottom = False,
    labelleft = False,
    labeltop = False,
    labelright = False,
    labelbottom = False
)
cbbox.set_facecolor([0,0,0,0.9])

for radargram in offset_video_radargrams_1617[:]:
    #if 'Y' in radargram.transect_id.split('/')[-1]:
    cb = ax.scatter(radargram['x'],radargram['y'] , c=radargram['velocity'], cmap='magma', s=30, zorder=4,vmin=90,vmax=170)
cbaxes = inset_axes(cbbox, '92%', '20%', loc = 'center')
cbar=fig.colorbar(cb,cax=cbaxes, orientation='horizontal',extend='both') #make colorbar
cbar.outline.set_edgecolor('white')
cbar.outline.set_linewidth(1)
cbar.ax.tick_params(labelsize=14, color='white', labelcolor='white')
cbar.set_label(r"$\mathbf{v}_{helicopter}$ [km hr$^{-1}$]", fontsize=15, color='white')
cbar.ax.xaxis.set_label_position('top')

cbar.ax.minorticks_on()

ax.set_xlim(bbox[0],bbox[2])
ax.set_ylim(bbox[1],bbox[3])
#ax.set_title(f"Window = {win_m} m, Overlap = {ovlp_m} m", fontsize=16)


# Label lakes A, B, C
ax.annotate('A', xy=(657000, -1446000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection,zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])
ax.annotate('B', xy=(664200, -1454000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection, zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])
ax.annotate('C', xy=(668500, -1458000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection,zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])




# Ax2
scalebar = AnchoredSizeBar(ax2.transData, 5000, '5 km', 'upper left', pad=1.5, color='black', frameon=False, size_vertical=300, fontproperties={'size': 14})
ax2.add_artist(scalebar)

#bbox = [650000,-1475000,680000,-1430000] #David_SGL2_full extent
# Glacial Flow Direction Arrow
ax2.annotate(
    '',
    xy=(659000, -1436000),      # arrow tip (downstream)
    xytext=(664000, -1431000),  # arrow tail
    arrowprops=dict(
        arrowstyle='-|>',       # filled arrow head
        color='black',
        lw=2,
        mutation_scale=20 ,      # controls head size
    ),
    transform=ps71_projection,
    zorder=10
)

ax2.text(664000, -1432000, ' Ice Flow\nDirection',
        fontsize=14, color='black', ha='left', va='center',zorder=10)

bbox = [650000,-1475000,680000,-1430000] #David_SGL2_full extent

# Remove borders
ax2.patch.set_facecolor("none")
for spine in ax2.spines.values():
    spine.set_visible(False)
ax2.set_xticks([])
ax2.set_yticks([])

for x, y in zip(xs_lake, ys_lake):
    ax.plot(x, y, color='white', linewidth=2.5, zorder=5)

# Add colorbar
k_cbar_anchor = (0,0)
cbbox = inset_axes(ax2, width=3,height=1,
                bbox_to_anchor=k_cbar_anchor,
                bbox_transform=ax2.transAxes, loc="center left")
[cbbox.spines[k].set_visible(False) for k in cbbox.spines]
cbbox.tick_params(
    axis = 'both',
    left = False,
    top = False,
    right = False,
    bottom = False,
    labelleft = False,
    labeltop = False,
    labelright = False,
    labelbottom = False
)
cbbox.set_facecolor([0,0,0,0.9])

for radargram in offset_video_radargrams_1819[:]:
    #if 'Y' in radargram.transect_id.split('/')[-1]:
    cb = ax2.scatter(radargram['x'],radargram['y'] , c=radargram['velocity'], cmap='magma', s=30, zorder=4,vmin=90,vmax=170)
cbaxes = inset_axes(cbbox, '92%', '20%', loc = 'center')
cbar=fig.colorbar(cb,cax=cbaxes, orientation='horizontal', extend='both') #make colorbar
cbar.outline.set_edgecolor('white')
cbar.outline.set_linewidth(1)
cbar.ax.tick_params(labelsize=14, color='white', labelcolor='white')
cbar.set_label(r"$\mathbf{v}_{helicopter}$ [km hr$^{-1}$]", fontsize=15, color='white')
cbar.ax.xaxis.set_label_position('top')

cbar.ax.minorticks_on()

ax2.set_xlim(bbox[0],bbox[2])
ax2.set_ylim(bbox[1],bbox[3])
#ax.set_title(f"Window = {win_m} m, Overlap = {ovlp_m} m", fontsize=16)

for x, y in zip(xs_lake, ys_lake):
    ax2.plot(x, y, color='white', linewidth=2.5, zorder=5)

# Label lakes A, B, C
ax2.annotate('A', xy=(657000, -1446000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection,zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])
ax2.annotate('B', xy=(664200, -1454000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection, zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])
ax2.annotate('C', xy=(668500, -1458000), color='white', fontsize=16, fontweight='bold',transform=ps71_projection,zorder=10,path_effects=[pe.withStroke(linewidth=3, foreground='black')])

# Set background gainsboro
fig.patch.set_facecolor('gainsboro')

fig.savefig(os.path.join(outdir, 'FigureS2.png'), dpi=300, bbox_inches='tight')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
## Figure S3 ##
def common_panel_elements_S3(ax, plot_dict, rad_vel):
    """
    Plot doppler width and lake outline map view.
    """

    bbox = [650000,-1475000,680000,-1430000] #David_SGL2_full extent

    # Remove borders
    ax.patch.set_facecolor("none")
    for spine in ax.spines.values():
        spine.set_visible(False)
    ax.set_xticks([])
    ax.set_yticks([])

    ax.set_xlim(bbox[0],bbox[2])
    ax.set_ylim(bbox[1],bbox[3])
    
    scalebar = AnchoredSizeBar(ax.transData, 5000, '5 km', 'upper left', pad=1.5, color='black', frameon=False, size_vertical=300, fontproperties={'size': 14})
    ax.add_artist(scalebar)

    # Glacial flow arrow
    ax.annotate(
    '',
    xy=(659000, -1436000),      # Tip
    xytext=(664000, -1431000),  # Tail
    arrowprops=dict(
        arrowstyle='-|>',       
        color='black',
        lw=2,
        mutation_scale=20 ,     
    ),
    transform=ps71_projection,
    zorder=10
    )
    ax.text(664000, -1432000, ' Ice Flow\nDirection',
        fontsize=14, color='black', ha='left', va='center',zorder=10)

    return ax

# Two histograms, 2016-2017 and 2018-2019 next to double difference plots
ps71_projection = ccrs.Stereographic(central_latitude=-90, central_longitude=0, true_scale_latitude=-71)
fig = plt.figure(figsize=(10, 12))
gs = fig.add_gridspec(2, 2,height_ratios=[2, 1])
ax1 = fig.add_subplot(gs[0, 0], projection=ps71_projection)
ax2 = fig.add_subplot(gs[0, 1], projection=ps71_projection)
ax3 = fig.add_subplot(gs[1, 0])
ax4 = fig.add_subplot(gs[1, 1])

# Maps
common_panel_elements_S3(ax1, plotting_dict, offset_video_radargrams_1617)
plot_outlines(ax1, evolving_outlines, DDInSAR_outlines, idx_1617, idx_1819)
cb = ax1.scatter(x_cross, y_cross, c=ridge_diff_1617-ridge_diff_velocity_corrected_1617, cmap='seismic', s=30, zorder=4,vmin=-250,vmax=250) 


common_panel_elements_S3(ax2, plotting_dict_1819, offset_video_radargrams_1819)
plot_outlines(ax2, evolving_outlines, DDInSAR_outlines, idx_1617, idx_1819)
cb = ax2.scatter(x_cross_1819, y_cross_1819, c=ridge_diff_1819-ridge_diff_velocity_corrected_1819, cmap='seismic', s=30, zorder=4,vmin=-250,vmax=250)

fig.set_facecolor('gainsboro')

# Add colorbar
k_cbar_anchor = (0,0)
cbbox = inset_axes(ax1, width=3.5,height=1,
                bbox_to_anchor=k_cbar_anchor,
                bbox_transform=ax1.transAxes, loc="center left")
[cbbox.spines[k].set_visible(False) for k in cbbox.spines]
cbbox.tick_params(
    axis = 'both',
    left = False,
    top = False,
    right = False,
    bottom = False,
    labelleft = False,
    labeltop = False,
    labelright = False,
    labelbottom = False
)
cbbox.set_facecolor([0,0,0,0.9])
cbaxes = inset_axes(cbbox, '92%', '20%', loc = 'center')
cbar=fig.colorbar(cb,cax=cbaxes, orientation='horizontal', extend='both') #make colorbar
cbar.outline.set_edgecolor('white')
cbar.outline.set_linewidth(1)
cbar.ax.tick_params(labelsize=14, color='white', labelcolor='white')
cbar.set_label("Uncorrected - Corrected [Hz]", fontsize=15, color='white')
cbar.ax.xaxis.set_label_position('top')

cbar.ax.minorticks_on()

# Add colorbar
k_cbar_anchor = (0,0)
cbbox = inset_axes(ax2, width=3.5,height=1,
                bbox_to_anchor=k_cbar_anchor,
                bbox_transform=ax2.transAxes, loc="center left")
[cbbox.spines[k].set_visible(False) for k in cbbox.spines]
cbbox.tick_params(
    axis = 'both',
    left = False,
    top = False,
    right = False,
    bottom = False,
    labelleft = False,
    labeltop = False,
    labelright = False,
    labelbottom = False
)
cbbox.set_facecolor([0,0,0,0.9])
cbaxes = inset_axes(cbbox, '92%', '20%', loc = 'center')
cbar=fig.colorbar(cb,cax=cbaxes, orientation='horizontal',extend='both') #make colorbar
cbar.outline.set_edgecolor('white')
cbar.outline.set_linewidth(1)
cbar.ax.tick_params(labelsize=14, color='white', labelcolor='white')
cbar.set_label("Uncorrected - Corrected [Hz]", fontsize=15, color='white')
cbar.ax.xaxis.set_label_position('top')

cbar.ax.minorticks_on()






# Histograms
# Combine data to get common bins
all_data = np.concatenate([ridge_diff_velocity_corrected_1617, ridge_diff_1617])
bins = np.linspace(all_data.min(), all_data.max(), 20) 

ax3.hist(ridge_diff_velocity_corrected_1617, bins=bins, color='purple',alpha=0.7, edgecolor='black')
ax3.hist(ridge_diff_1617, bins=bins, color='orange',alpha=0.7, edgecolor='black')
# Boxplot
#ax.boxplot(abs_ridge_diff, vert=False, patch_artist=True, boxprops=dict(facecolor='purple', color='black'), medianprops=dict(color='yellow'))
ax3.set_xlabel('Abs Crossover Difference [Hz]', fontsize=16)
ax3.set_ylabel('Count', fontsize=16)
ax3.tick_params(labelsize=14)
ax3.text(0.95, 0.6, f'2016-2017', transform=ax3.transAxes, fontsize=14, verticalalignment='top', horizontalalignment='right')

ax3.legend(['Point-Velocity', 'Average Velocity'], fontsize=14, loc='upper right', frameon=False)


# Combine data to get common bins
all_data = np.concatenate([ridge_diff_velocity_corrected_1819, ridge_diff_1819])
bins = np.linspace(all_data.min(), all_data.max(), 26) 

ax4.hist(ridge_diff_velocity_corrected_1819, bins=bins, color='purple',alpha=0.7, edgecolor='black')
ax4.hist(ridge_diff_1819, bins=bins, color='orange',alpha=0.7, edgecolor='black')
# Boxplot
#ax.boxplot(abs_ridge_diff, vert=False, patch_artist=True, boxprops=dict(facecolor='purple', color='black'), medianprops=dict(color='yellow'))
ax4.set_xlabel('Abs Crossover Difference [Hz]', fontsize=16)
ax4.set_ylabel('Count', fontsize=16)
ax4.tick_params(labelsize=14)
ax4.text(0.95, 0.6, f'2018-2019', transform=ax4.transAxes, fontsize=14, verticalalignment='top', horizontalalignment='right')

ax4.legend(['Point-Velocity', 'Average Velocity'], fontsize=14, loc='upper right', frameon=False)

fig.savefig(os.path.join(outdir, 'FigureS3.png'), dpi=300, bbox_inches='tight')
